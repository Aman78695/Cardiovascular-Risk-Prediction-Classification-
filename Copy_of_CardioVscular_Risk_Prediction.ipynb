# %% [markdown]
# <a href="https://colab.research.google.com/github/Aman78695/Cardiovascular-Risk-Prediction-Classification-/blob/main/Copy_of_CardioVscular_Risk_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - CardioVascular Risk Prediction
#
# ![Heart-Attack-Concept (1).jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ##### **Project Type**    - Classification/Supervised
# ##### **Contribution**    - Individual

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# **SUMMARY**
#
# **CARDIOVASCULAR RISK PREDICTION**
#
#
#
# •	**INTRODUCTION**
#
# Cardiovascular disease has been regarded as the most severe and lethal disease in humans. The increased rate of cardiovascular diseases with a high mortality rate is causing significant risk and burden to the healthcare systems worldwide. Cardiovascular diseases are more seen in men than in women particularly in middle or old age , although there are also children with similar health issues . According to data provided by the WHO, one-third of the deaths globally are caused by the heart disease. CVDs cause the death of approximately 17.9 million people every year worldwide and have a higher prevalence in Asia.
#
# •	**PROBLEM STATEMENT**
#
# Predicting coronary heart disease in advance helps raise awareness for the disease. Preventive measurements like changing diet plans and exercise can slow down the progression of CHD. Early prediction can result in early diagnosis. So, we can treat the disease at an early stage and avoid more invasive treatment.
# The goal is to predict whether the patient has a 10-year risk of future coronary heart disease (CHD).
#
# •	**TOOLS REQUIRED**
#
# To do analysis on Cardiovascular data we used language python. In python we have various libraries which we must import like NumPy, Pandas, Matplotlib and Seaborn, Scikit-Learn.
#
#
# •	**ACTIVITY**
#
# •	First step involved is** understanding the data **and getting answers to some basic questions like; What is the data about? How many rows or observations are there in it? How many features are there in it? What are the data types? Are there any missing values? And anything that could be relevant and useful to our investigation.
#
#
# •	**Handling missing values** is an important skill in the data analysis process.
#
#
# •	**Exploratory data analysis** is a crucial part of data analysis. It involves exploring and analysing the dataset given to find out patterns, trends and conclusions to make better decisions related to the data, often using statistical graphics and other data visualization tools to summarize the results.
#
#
# •	***Data manipulation ***involves manipulating and changing our dataset before feeding it to various regression machine learning models. This involves keeping important features, outlier treatment, feature scaling and creating dummy variables if necessary.
#
#
# •	In statistics, an outlier is a data point that differs significantly from other observations.
#
#
# •***	Feature Scaling ***is a technique to standardize the independent features present in the data in a fixed range. It is done to prevent biased nature of machine learning algorithms towards features with greater values and scale.
#
#
# •***	CONCLUSION***
# •	As age increases the risk of getting diagnosed with heart disease also increases.
#
#
# •	Cigarette consumption is also a major factor that causes CHDs.
#
#
# •	Patients having Diabetes and cholesterol problems show a higher risk of CHDs.
#
#
# •	Patients having high glucose levels are more prone to CHDs.
#
#
# •	Patients with a history of “strokes” have a higher chance of developing CHDs.
#
#
# •	Patients with high BMI(Body Mass Index) are at more risk of getting diagnosed
#  with CHDs.
#
#
# •	Finally, we can say that XGBoost Classifier has performed best among all the models with the accuracy of 76% & f1-score of 0.71. It is by far the second highest score we have achieved. So, It’s safe to say that XGBoost Classifier provides an optimal solution to our problem.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# GitHub Link:- https://github.com/Aman78695/CardioVascular-Risk-Prediction

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **Cardiovascular diseases** (CVD) are among the most common serious illnesses affecting human health. CVDs may be prevented or mitigated by early diagnosis, and this may reduce mortality rates. Identifying risk factors using machine learning models is a promising approach. We would like to propose a model that incorporates different methods to achieve effective prediction of heart disease. For our proposed model to be successful, we have used efficient Data Collection, Data Pre-processing and Data Transformation methods to create accurate information for the training model.
#
# New hybrid classifiers like **Decision Tree Bagging Method (DTBM), Random Forest Bagging Method (RFBM), K-Nearest Neighbours, Bagging Method (KNNBM), AdaBoost Boosting Method (ABBM), and Gradient Boosting Boosting Method (GBBM)** are developed by integrating the traditional classifiers with bagging and boosting methods, which are used in the training process.
#
#
# Predicting coronary heart disease in advance helps raise awareness for the disease. Preventive measurements like changing diet plans and exercise can slow down the progression of CHD. Early prediction can result in early diagnosis. So, we can treat the disease at an early stage and avoid more invasive treatment.
#
# We have been provided with the dataset which provides the patients’ information. It includes over 4,000 records and 15 attributes. Variables Each attribute is a potential risk factor. There are both demographic, behavioural, and medical risk factors like sex,age,smoking or not,how many cigarettes per day,and other medical history.
#
#
# The goal is to predict whether the patient has a 10-year risk of future coronary heart disease (CHD).

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 15 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]
#
#
#
#
#
# 6. You may add more ml algorithms for model creation. Make sure for each and every algorithm, the following format should be answered.
#
#
# *   Explain the ML Model used and it's performance using Evaluation metric Score Chart.
#
#
# *   Cross- Validation & Hyperparameter Tuning
#
# *   Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.
#
# *   Explain each evaluation metric's indication towards business and the business impact pf the ML model used.

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
# Import Libraries

import numpy as np  #to perform a wide variety of mathematical operations on arrays
import pandas as pd  #for working with relational or labeled data both easily and intuitively.
import matplotlib.pyplot as plt  #for data visualisation
import seaborn as sns  #for data visualisation

import scipy  # for scientific computation
from sklearn.linear_model import LogisticRegression #classification algorithm
from sklearn .preprocessing import MinMaxScaler,StandardScaler  #Transform features by scaling each feature to a given range.
from sklearn .preprocessing import LabelEncoder,OneHotEncoder    #convert categorical text data into model-understandable numerical data
from sklearn.model_selection import train_test_split  #method used to split our data into train and test sets.
from sklearn.model_selection import GridSearchCV,RandomizedSearchCV   #technique to search through the best parameter values from the given set of the grid of parameters
from sklearn.tree import DecisionTreeClassifier  #ML algorithm use for both classification and regression
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier  #combines several decision trees to produce better predictive performance
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score,roc_auc_score   #to measure classification performance.
from sklearn.decomposition import PCA    #dimensionality reduction technique
from sklearn.naive_bayes import GaussianNB  #ML algorithm
from imblearn.over_sampling import SMOTE   #use to handle imbalance datasets
from sklearn.neighbors import KNeighborsClassifier  #ML algorithm
from sklearn import svm  #ML algorithm
from sklearn.tree import DecisionTreeClassifier  #ML algorithm
from sklearn.ensemble import RandomForestClassifier #ML algorithm
from xgboost import XGBClassifier   #ML algorithm
from sklearn.ensemble import AdaBoostClassifier  #ML algorithm
from sklearn.neighbors import KNeighborsClassifier  #ML algorithm
import xgboost as xgb
from sklearn.ensemble import GradientBoostingClassifier   #ML algorithm
from sklearn.preprocessing import StandardScaler,MinMaxScaler   #Transform features by scaling each feature to a given range.

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
#reading csv file and converting into dataframe
df=pd.read_csv('/content/data_cardiovascular_risk.csv')

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
#checking first five rows of data
df.head(50)

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
df.shape

# %% [markdown]
# There are 3390 rows and 17 columns in the datasets

# %%
#creating the list of columns
total_columns=list(df.columns)
total_columns

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
#collecting information about datasets i.e. shape of datasets,name of features,null values in column,datatype of the elements in datasets
df.info()

# %% [markdown]
# We have columns with integer type,object type and float type datasets.Also there are some columns with missing values.

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
df.duplicated().sum()

# %%
df.describe()

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
df.isnull().sum()

# %%
#creating the list of those columns which has the null values
columns_null_values=[i for i in total_columns if df[i].isnull().sum()!=0]
columns_null_values

# %% [markdown]
# Now columns_null_values contain those columns which have the null values these null values has to be treated either by filling it up with mean,median,mode or 0 ,the corresponding rows can also be dropped but this can only be decided based on the business problem and going through the distribution plot of each columns.

# %%
# Visualizing the missing values
#plotting the distribution plot for those columns which have the null values
plt.figure(figsize=(12,15))
for i,j in enumerate(columns_null_values):
  sns.set_palette('PuBuGn_r')
  plt.subplot(4,2,i+1)
  sns.distplot(df[j],bins=20)

# %%
#calculating the skewness values for those columns which have null values
for i in columns_null_values:
 print(f"the skewness of the column",i,"is:","  " ,df[i].skew())

# %% [markdown]
# **Skewness** is used to measure the level of asymmetry in our graph. It is the measure of asymmetry that occurs when our data deviates from the norm.
#
# If skewness value is between:
#
# **-0.5 and 0.5, the distribution of the value is almost symmetrical**
#
#
#
# **-1 and -0.5, the data is negatively skewed,**
#
# **and if it is between 0.5 to 1, the data is positively skewed.**
#
#
# If the skewness is lower than -1 (negatively skewed) or greater than 1 (positively skewed), the data is highly skewed.

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# **Data Description:**
#
# The dataset provides the patients’ information. It includes over 3390 records and 17 attributes. Variables Each attribute is a potential risk factor. There are both demographic, behavioural, and medical risk factors.
#
#
# • **Sex**: male or female("M" or "F")
#
# • **Age**: Age of the patient
#
#
# **Behavioural:**
#
# • **is_smoking:** whether the patient is a current smoker ("YES" or "NO")
#
# • **Cigs Per Day:** the number of cigarettes that the person smoked on average in one day
#
# **Medical(History):**
#
# •*** BP Meds: ***whether the patient was on blood pressure medication
#
# • **Prevalent Stroke:** whether the patient had previously had a stroke
#
# •*** Prevalent Hyp:*** whether the patient was hypertensive
#
# •*** Diabetes:*** whether the patient had diabetes (Nominal) Medical(current)
#
# **• Tot Chol:** total cholesterol level
#
# •*** Sys BP:*** systolic blood pressure
#
# •** Dia BP:** *diastolic blood pressure
#
# **• BMI:** Body Mass Index
#
# **• Heart Rate:** heart rate
#
# **• Glucose:** glucose level
#
# **• CHD: 10-year risk of coronary heart disease** CHD(binary: “1”, means “Yes”, “0” means “No”)

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
#creating the list of columns
total_columns=list(df.columns)
total_columns

# %%
# Dataset Describe
df.describe()

# %% [markdown]
# ### Variables Description

# %% [markdown]
# Answer Here

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for i in total_columns:
  print(df[i].value_counts())

# %% [markdown]
# ## 3. ***Data Wrangling***
#
# Data Munging, commonly referred to as Data Wrangling, is the cleaning and transforming of one type of data to another type to make it more appropriate into a processed format. Data wrangling involves processing the data in various formats and analyzes and get them to be used with another set of data and bringing them together into valuable insights. It further includes data aggregation, data visualization, and training statistical models for prediction. data wrangling is one of the most important steps of the data science process. The quality of data analysis is only as good as the quality of data itself, so it is very important to maintain data quality.

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.

# %%
#creating a copy of original dataframe
df1=df.copy()

# %%
#dropping irrelevant features like id and education from dataframe
df1.drop(columns='id',axis=1,inplace=True)

# %%
df1.drop(columns='education',axis=1,inplace=True)

# %%
#converting 'YES' to 1 and 'NO' to 0 in is_smoking column
df1['is_smoking']=np.where(df1['is_smoking']=='YES',1,0)

# %%
#converting 'F' to 0 and 'M' to 1
df1['sex']=np.where(df1['sex']=='F',0,1)

# %% [markdown]
# ## **filling the null values with median as most of the columns with null values are rightly skewed.**

# %%
#creating copy of the original dataframe
df2=df1.copy()
df2.head()

# %%
#creating list of new columns after dropping some of the columns
total_columns_after_drop=list(df2.columns)

# %%
#checking the columns with null values
columns_with_null_values=[i for i in total_columns_after_drop if df2[i].isnull().sum()!=0]
columns_with_null_values

# %%
#filling the null values with median
for i in columns_with_null_values:
 df2[i].fillna(df2[i].median(),inplace=True)

# %%
#cheking the null values
df2.isnull().sum()

# %%
#plotting the dist plot of the columns after filling the null values
plt.figure(figsize=(10,12))
for i,j in enumerate(columns_with_null_values):
  sns.set_palette('flag_r')
  plt.subplot(3,2,i+1)
  sns.distplot(df2[j],bins=20)

# %%
#calculating the skewness values for those columns which was having null values after filling the null values
for i in columns_with_null_values:
 print(f"the skewness of the column",i,"is:","  " ,df2[i].skew())

# %% [markdown]
# **we can clearly see the skewness of the data has increased a little bit after filling the null values but its ok we can treat it during outliers treatment.**

# %% [markdown]
# ## **#Detecting Outliers through boxplot,distplot,and violinplot.**

# %%
#plotting the boxplot for checking the outliers
plt.figure(figsize=(20,30))
sns.boxplot(data=df2,orient='h')

# %% [markdown]
# We can clearly see through the boxplot that there are some columns which have value either 0 or 1 hence depicting no outliers like 'TenYearCHD', 'diabetes', ' prevalentHyp', 'prevalentStroke', 'BPMeds', 'is_smoking', 'sex,.

# %% [markdown]
# #checking imbalance in the datasets

# %%
df2['sex'].value_counts()

# %%
df2['is_smoking'].value_counts()

# %%
df2['BPMeds'].value_counts()

# %%
df2['prevalentStroke'].value_counts()

# %%
df2['prevalentHyp'].value_counts()

# %%
df2['diabetes'].value_counts()

# %% [markdown]
# We can clearly observe that the value counts of some of the columns are imbalance hence it can affect our model so it is better to drop these columns.

# %% [markdown]
# #Selecting those columns which are categorical in nature and doing univariate analysis

# %%
#creating a list of categorical columns
cat_columns=['sex','is_smoking','BPMeds','prevalentStroke','prevalentHyp','diabetes']

# %%
#value counts of each categorical column through barchart(Univariate Analysis)
plt.figure(figsize=(12,20))
for i,j in enumerate(cat_columns):
 sns.set_palette('husl')
 plt.subplot(3,2,i+1)
 sns.countplot(x=df2[j])
plt.show()

# %%
#value counts of each categorical columns through pie chart in the form of percentage(Univariate Analysis)
plt.figure(figsize=(12,20))
for i,j in enumerate(cat_columns):
 sns.set_palette('cubehelix')
 plt.subplot(3,2,i+1)
 df2[j].value_counts().plot(kind='pie',autopct='%.1f%%')
plt.show()

# %% [markdown]
# #Selecting those columns which are continuous in nature and doing univariate analysis through boxplot,distplot and violinplot

# %%
#plotting the boxplot for those columns whioch have continuous values indicating the outliers.(Univariate Analysis)
cont_columns=['totChol','sysBP','diaBP','BMI','heartRate','glucose']
plt.figure(figsize=(8,15))
for i,j in enumerate(cont_columns):
  sns.set_palette('PuBuGn_r')
  plt.subplot(4,2,i+1)
  sns.boxplot(x=df2[j])

# %% [markdown]
# We can clearly observe from
# the boxplot that glucose have
# maximum number of outliers
# indicating large value of
# skewness, also heartRate has
# less number of outliers
# indicating less value of
# skewness.

# %%
#plotting displot to look for skewness(Univariate Analysis)
cont_columns=['totChol','sysBP','diaBP','BMI','heartRate','glucose']
plt.figure(figsize=(12,20))
for i,j in enumerate(cont_columns):
 sns.set_palette('flag_r')
 plt.subplot(4,2,i+1)
 sns.distplot(x=df2[j])
plt.show()

# %% [markdown]
# **Most of the datas are rightly skewed.**

# %%
#drawing violinplot(Univariate Analysis)
cont_columns=['totChol','sysBP','diaBP','BMI','heartRate','glucose']
plt.figure(figsize=(12,20))
for i,j in enumerate(cont_columns):
  sns.set()
  plt.subplot(4,2,i+1)
  sns.violinplot(x=df2[j],palette='CMRmap_r')

# %% [markdown]
# In general, violin plots are a method of plotting numeric data and can be considered a combination of the box plot with a kernel density plot. In the violin plot, we can find the same information as in the box plots:
#
# median (a white dot on the violin plot)
#
# interquartile range (the black bar in the center of violin)
#
# the lower/upper adjacent values (the black lines stretched from the bar) — defined as first quartile — 1.5 IQR and third quartile + 1.5 IQR respectively.
#
# These values can be used in a simple outlier detection technique (Tukey’s fences) — observations lying outside of these “fences” can be considered outliers.
#
# The unquestionable advantage of the violin plot over the box plot is that aside from showing the abovementioned statistics it also shows the entire distribution of the data. This is of interest, especially when dealing with multimodal data, i.e., a distribution with more than one peak.

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Some of the insights which can be found after data wrangling are as follows:-
#
#
# *   We have sufficient number of records to train our model almost 4000 records.
#
#
# * Each variable of dataset is potential risk of heart disease leaving out some of the irrevelant columns like id,education.
#
#
#
# *   Most of the categorical columns are imbalanced for example:-sex,is_smoking,BPMeds,prevalentStroke,prevalentHyp,diabetes
#
#
#
#
#
# *   Most of the continuous columns have assymetrical data ppresent in it indicating outliers and skewness,like 'totChol','sysBP','diaBP','BMI','heartRate','glucose'.
#
#
#
# *   The null values present in the datasets were filled by median as most of it are rightly skewed.
#
#
#
#
#
# *  Some of the columns have only two values either 0 or 1 like 'sex',  'is_smoking', 'BPMeds' , 'prevalentStroke', 'prevalentHyp', 'diabetes'.Some of them are imbalance which can effect the model during training.
#
#
#
# *   The boxplot and the value of skewness tell the same story about datasets more the value of skewness more will be the outliers.
#
#
#
#
# *   We will do log transformation later.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***
#
# Data visualization is the graphical representation of information and data. By using visual elements like charts, graphs, and maps, data visualization tools provide an accessible way to see and understand trends, outliers, and patterns in data. Additionally, it provides an excellent way for employees or business owners to present data to non-technical audiences without confusion.

# %%
df2.head()

# %% [markdown]
# #### Chart - 1

# %% [markdown]
# **Bivariate Analysis**

# %%
# Chart - 1 visualization code
#Checking collinearity of diaBP and sysBP
sns.jointplot(x=df2['sysBP'],y=df2['diaBP'],kind='reg')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?
#
# A Jointplot comprises three plots. Out of the three, one plot displays a bivariate graph which shows how the dependent variable(Y) varies with the independent variable(X). Another plot is placed horizontally at the top of the bivariate graph and it shows the distribution of the independent variable(X). The third plot is placed on the right margin of the bivariate graph with the orientation set to vertical and it shows the distribution of the dependent variable(Y). It is very helpful to have univariate and bivariate plots together in one figure.

# %% [markdown]
# **Systolic blood pressure**
#
#
#
# *   The pressure exerted when the heartbeats
# *   In infants –95mmHg. In adults– 90-120 mmHg. Age 6 to 9 –100 mmHg.
#
#
# *  The systolic pressure is high
#
# **Diastolic blood pressure**
#
#
# *   The pressure exerted on the walls of the arteries when the heart muscles relax in between two beats
# *   In infants–65 mm Hg. In adults– 60-80 mmHg. Age 6 – 9 — 65 mmHg.
#
#
# *   The diastolic pressure is low
#
#
# Through this chart I wanted to extract the insights that whether, if sysBP is increasing the diaBP is increasing or not also wanted to check that the value of diaBP should be lower than sysBP.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We can clearly see that **sysBP** and diaBP are positively correlated and there are many people who have higher value of sysBP and diaBP than normal range indicating more prone to chronic heart diseases.And also the value of diaBP is lower than sysBP for a particular person which is a generalised behaviour.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?

# %% [markdown]
# Blood pressure is a serious health problem which affects nearly 40 to 50 per cent of the total population.Blood pressure is the force of blood against the arteries. An individual should maintain a normal blood pressure from 90 – 120 / 60 – 80 mm Hg. Blood pressure is given by two numbers, with one above or before the other – 120/80.120 – This is called systolic pressure and 80 – This is called diastolic pressure.

# %% [markdown]
# #### Chart - 2

# %% [markdown]
# **Bivariate Analysis**

# %%
# Chart - 2 visualization code
#checking the collinearity of diabetes and glucose level of blood
plt.figure(figsize = (15,8))
sns.set_palette('bwr_r')
sns.jointplot(x=df2['glucose'],y=df2['diabetes'],kind='reg')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A Jointplot comprises three plots. Out of the three, one plot displays a bivariate graph which shows how the dependent variable(Y) varies with the independent variable(X). Another plot is placed horizontally at the top of the bivariate graph and it shows the distribution of the independent variable(X). The third plot is placed on the right margin of the bivariate graph with the orientation set to vertical and it shows the distribution of the dependent variable(Y). It is very helpful to have univariate and bivariate plots together in one figure.
#
#
# When we have diabetes, our blood sugar (aka blood glucose) levels may be consistently high. Over time, this can damage our body and lead to many other problems.
#
# A fasting blood sugar level of 99 mg/dL or lower is normal, 100 to 125 mg/dL indicates we have prediabetes, and 126 mg/dL or higher indicates we have diabetes.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the above plot it can be clearly interpreted that low value of glucose means non-diabetic and high value of glucose means diabetic,although there are some samples which are diabetic having low value of glucose indicting the effect of some other factors.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# A strong link between diabetes and heart disease is now well established. Women with diabetes have an even greater risk of heart disease compared with those of similar age who do not have diabetes. In fact, cardiovascular disease leading to heart attack or stroke is by far the leading cause of death in both men and women with diabetes.
#
# there are steps to take to reduce our risk for heart disease if we have diabetes."
#
#
#
# *   Control your weight.
# *   Get regular physical activity.
#
#
# *   Maintain optimal control over glucose.
# *   Lower your LDL cholesterol (the "bad" type).
#
#
# *   Control your blood pressure.

# %% [markdown]
# #### Chart - 3

# %% [markdown]
# **Univariate Analysis**

# %%
# Chart - 3 visualization code
#Are diabetic patients at more risk of coronary heart disease ??
my_palette = {0 : 'orange' , 1 : 'teal'}
plt.figure(figsize = (10,10))
sns.countplot(x = df2['diabetes'], hue = df2['TenYearCHD'], palette = my_palette)#counting the no of people with diabetese and whether they are prone to CHD or not
plt.title("Are diabetic patients at more risk of coronary heart disease?")
plt.legend(['No Risk','At Risk'])
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# countplot() method is used to Show the counts of observations in each categorical bin using bars.It is used for univariate analysis.
#
# I wanted to observe the no of people who are at risk of heart disease and also whether the person is diabetic or not.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Looking atc the plot ahead we can interpret that the non diabetic people are at low risk of heart disease but the diabetic people have almost equal proportion of beeing having heart disease.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# From the above plot it can be concluded that only diabetes is not the sole factor which causes heart disease.So we must also know the other medical factors of patients.

# %% [markdown]
# #### Chart - 4

# %% [markdown]
# **Bivariate Analysis**

# %%
# Chart - 4 visualization code
#relplot for age and CHD for female(0) and male(1)
plt.figure(figsize = (20,12))
sns.relplot(x="age", y="TenYearCHD", hue="sex",  kind="line", data=df2,ci=None)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The Seaborn Relational Plot (relplot) allows us to visualise how variables within a dataset relate to each other.
#
# The above plot is drawn to check which group of people according to age are more prone to CHD,and it is checked both for male and female.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the above relplot it can be concluded that with increase in age people are more prone to CHD and this trend is more for male than female.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Heart disease—and the conditions that lead to it—can happen at any age. High rates of obesity and high blood pressure among younger people (ages 35–64) are putting them at risk for heart disease earlier in life.
#
# In both sexes, the risk of CHD increased markedly with age. In most populations, serum total cholesterol increases as age increases. In men, this increase usually levels off around the age of 45 to 50 years, whereas in women, the increase continues sharply until the age of 60 to 65 years.

# %% [markdown]
# #### Chart - 5

# %% [markdown]
# **Bivariate Analysis**

# %%
# Chart - 5 visualization code
plt.figure(figsize = (10,10))
ax = sns.boxplot(x = df2['sex'], y = df2['age'], hue = df2['TenYearCHD'], palette = my_palette)# sex '0' indicating female and '1' indicating male
plt.title("Which Age Group which is more vulnerable to CHD")
handles, _ = ax.get_legend_handles_labels()          
ax.legend(handles, ['No Risk','At Risk'], loc="best")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Due to the five-number data summary, a box plot can handle and present a summary of a large amount of data. A box plot consists of the median, which is the midpoint of the range of data; the upper and lower quartiles, which represent the numbers above and below the highest and lower quarters of the data and the minimum and maximum data values. Organizing data in a box plot by using five key concepts is an efficient way of dealing with large data

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# It can be observed that whether male and female with higher age are more prone to CHD.Female with age between 48 and 62 are more prone to heart disease,and male betwwen the age of 46 and 60 are more prone to CHD.
#
# Box  shows the relationship between the variables 'sex', 'age', and 'TenYearCHD' . The x-axis is 'sex' (with '0' indicating female and '1' indicating male), the y-axis is 'age', and the hue will be 'TenYearCHD' (with different colors indicating the risk of CHD).

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# A heart attack can occur at any age. We are never too young to start living healthier. If you’re over 40, or if you have multiple risk factors, work closely with your health care team to address your risk of developing cardiovascular disease. A team-based approach is the best way to prevent heart disease and stroke. You and your health care team can build a prevention plan that works for you.
#
# If you’re prescribed medications to manage blood sugar, cholesterol, blood pressure or other conditions, take them as directed.
#
# Talk about challenges in your life that may affect your health and ask for support. If you have concerns about accessing care, affording your medications or finding transportation to and from medical appointments, ask your health care team about finding resources.

# %% [markdown]
# #### Chart - 6

# %% [markdown]
# **Univariate Analysis**

# %%
# Chart - 6 visualization code
#Are patients with blood pressure on medication at more risk of coronary heart disease ??
my_palette = {0 : 'orange' , 1 : 'teal'}
plt.figure(figsize = (10,10))
sns.countplot(x = df2['BPMeds'], hue = df2['TenYearCHD'], palette = my_palette)
plt.title("Are patients on BP medication at more risk of CHD ?")
plt.legend(['No Risk','At Risk'])
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# countplot() method is used to Show the counts of observations in each categorical bin using bars.It is used for univariate analysis.
#
# I wanted to observe the no of people who are at risk of heart disease and also whether the person is on blood pressure medication or not.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# High blood pressure (BP) is one of the most important risk factors for cardiovascular disease (CVD), which is the leading cause of mortality.From the above plot it can be concluded that the patients who are not taking blood pressure medicine are at low risk of CHD although there are about 500 patients who are not taking BP medicines and are at risk of CHD,indicating some other factors.
#
# For those patients who are taking BP medicines are equally at risk of CHD.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Regardless of its exact contribution, high BP is a major risk factor for development of CVD. Prevention of the age-related increase in BP would substantially reduce the vascular consequences usually attributed to aging. It is time to focus greater attention on initiatives for prevention of the typical age-related increase in BP in addition to control of high BP in those with established hypertension. Even partial improvement in the age-related increase in BP would eliminate a large proportion of the existing burden of BP-related CVD.

# %% [markdown]
# #### Chart - 7

# %% [markdown]
# **Bivariate Analysis**

# %%
# Chart - 7 visualization code
#Are Total Cholestrol levels related to coronary heart disease ??
plt.figure(figsize = (10,10))
sns.boxplot(df2['TenYearCHD'], df2['totChol'], palette = my_palette)
plt.title("Are total cholestrol levels related to CHD ??")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Due to the five-number data summary, a box plot can handle and present a summary of a large amount of data. A box plot consists of the median, which is the midpoint of the range of data; the upper and lower quartiles, which represent the numbers above and below the highest and lower quarters of the data and the minimum and maximum data values. Organizing data in a box plot by using five key concepts is an efficient way of dealing with large data
#
# I wanted to observe the effect of cholestrol level and its relation with CHD.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# This indicates that cholestrol level is not the sole deciding factor for predicting whether the person gets coronary heart disease or not. People with similar levels of cholestrol have got coronary heart disease as well as are free from coronary heart disease. Clearly, there is no direct correlation of coronary heart disease with the cholestrol level.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Cholesterol is a waxy substance found in our blood. Our body needs cholesterol to build healthy cells, but high levels of cholesterol can increase our risk of heart disease.
#
# With high cholesterol, we can develop fatty deposits in our blood vessels. Eventually, these deposits grow, making it difficult for enough blood to flow through our arteries. Sometimes, those deposits can break suddenly and form a clot that causes a heart attack or stroke.
#
# High cholesterol can be inherited, but it's often the result of unhealthy lifestyle choices, which make it preventable and treatable. A healthy diet, regular exercise and sometimes medication can help reduce high cholesterol.

# %% [markdown]
# #### Chart - 8

# %% [markdown]
# **Univariate Analysis**

# %%
# Chart - 8 visualization code
#Whether a person who had a stroke earlier more prone to CHD?
plt.figure(figsize = (10,10))
my_palette = {0 : 'orange' , 1 : 'teal'}
sns.countplot(x = df2['prevalentStroke'], hue = df2['TenYearCHD'], palette = my_palette)
plt.title("Whether a person who had a stroke earlier more prone to CHD?? ")
plt.legend(['No Risk' , 'At Risk'])
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# countplot() method is used to Show the counts of observations in each categorical bin using bars.It is used for univariate analysis.
#
# prevalentStroke means if a patient has any history of stroke or not.(stroke) In medicine means, a loss of blood flow to part of the brain, which damages brain tissue. Strokes are caused by blood clots and broken blood vessels in the brain.
#
# Through the countplot I wanted to calculate the no of patients who are at risk of CHD or not and also whether they are having the history of stroke or not.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the above plot it can be clearly seen that those who donot have history of stroke are less prone to CHD but there are about 500 patients who donot have history of stroke still they are pron to CHD indicating some other factors.
#
# There are very less people who have history of stroke and are prone to CHD.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Heart attacks and strokes are closely related. Both are most often caused by the same health problems, such as cardiovascular disease. They also share many of the same risk factors, including lifestyle and family history.Stroke is similar to a heart attack, but it affects the blood vessels in the brain instead of the heart.
#
# Healthy diet, regular physical activity, and not using tobacco products are the keys to prevention. Checking and controlling risk factors for heart disease and stroke such as high blood pressure, high cholesterol and high blood sugar or diabetes is also very important.

# %% [markdown]
# #### Chart - 9

# %% [markdown]
# **Bivariate Analysis**

# %%
# Chart - 9 visualization code
#Plotting boxplot for BMI
plt.figure(figsize = (10,10))
sns.boxplot(df2['TenYearCHD'], df2['BMI'], palette = my_palette)
plt.title("Are patients with BMI at risk of CHD?")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Due to the five-number data summary, a box plot can handle and present a summary of a large amount of data. A box plot consists of the median, which is the midpoint of the range of data; the upper and lower quartiles, which represent the numbers above and below the highest and lower quarters of the data and the minimum and maximum data values. Organizing data in a box plot by using five key concepts is an efficient way of dealing with large data.
#
# I wanted to observe the effect of Body Mass Index of the patients on Heart Disease.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# BMI for those people who are not prone to CHD are between 23 to 28 whereas those who are prone to CHD their BMI is between the range 24 to 29.
# So clearly there is not huge difference hence we can conclude that BMI is not the good indicator of CHD.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 10

# %% [markdown]
# **Univariate Analysis**

# %%
# Chart - 10 visualization code
# plot histogram to see the distribution of the data
fig = plt.figure(figsize = (15,20))
ax = fig.gca()
df2.hist(ax = ax)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The histogram is a popular graphing tool. It is used to summarize discrete or continuous data that are measured on an interval scale. It is often used to illustrate the major features of the distribution of the data in a convenient form.The data points are grouped and rendered based on the bin value. The entire range of data values is divided into a series of non-overlapping intervals.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the above distribution plot it can be observed that there are some columns which are not good indicator of CHD as they have imbalanced data like 'BPMeds', 'prevalentStroke' , 'diabetes'...so its better to drop these columns.
#
#
#
# *  Most of the patients are aged between 35 and 65.
#
#
#
# *   The no of people who is smoking or not smoking are almost same.
#
#
# *   Older age people consumes less cigarrete per day.
#
#
# *   Most of the patients are not taking BP medicine
#
# *   Most of the patients are non diabetic.
#
# *   Most of the patients have cholestrol level between 200 to 350
#
#
# *   Glucose level are between 0 to 150
#
# *   Heart rate is betwwen 50 to 120

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes the gained insights help creating a positive business impact as one can alyse the variations in the features and can also conclude the ranges in which most of the values are falling for a particular feature.

# %% [markdown]
# #### Chart - 11

# %% [markdown]
# **Univariate Analysis**

# %%
# Chart - 11 visualization 
#countplot for those who are prone to CHD and for those who are not prone to CHD
my_palette = {0 : 'orange' , 1 : 'teal'}
sns.countplot(df2['TenYearCHD'],palette=my_palette)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# ountplot() method is used to Show the counts of observations in each categorical bin using bars.It is used for univariate analysis.
#
# I wanted to check if there is any imbalance in the target variable datasets.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# It can be clearly seen that the data in target varible datasets are imbalanced and it needs to be balanced else it can affect our model and our model will be biased.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes it helped in creating positive business impact as imbalance target variable leads to a biased ML model so we need to rectify it before training our model.

# %% [markdown]
# #### Chart - 12

# %% [markdown]
# **Bivariate Analysis**

# %%
# Chart - 12 visualization code
#scatterplot to show the imbalance in the target variable
plt.figure(figsize=(10,8))
sns.scatterplot(x=df2['totChol'],y=df2['glucose'],hue=df2['TenYearCHD'],palette='husl')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A scatter plot (aka scatter chart, scatter graph) uses dots to represent values for two different numeric variables. The position of each dot on the horizontal and vertical axis indicates values for an individual data point. Scatter plots are used to observe relationships between variables.
#
# A common modification of the basic scatter plot is the addition of a third variable. Values of the third variable can be encoded by modifying how the points are plotted. For a third variable that indicates categorical values (like TenYearCHD), the most common encoding is through point color. Giving each point a distinct hue makes it easy to show membership of each point to a respective group.
#
# I picked the specific chart as I wanted to see the imbalance in the datasets TenYearCHD.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the above plot it can be concluded that glucose and total cholestrol level of a person are almost linearly correlated.The glucose levels are between 50 to 150 whereas totalcholestral levels are between 110 to 400.But most of the people are not at risk of CHD indicating imbalance in the datasets.
#
# We can clearly see that the 0 datapoint of TenYearCHD is dominating over 1 hence we have to resample this through SMOTE.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes it helped as without balancing the datasets of target variables our model will be biased.

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code
#using smote to resample the datasets so that it can be balanced
from imblearn.over_sampling import SMOTE

smote = SMOTE()

# fit predictor and target variable
x_smote, y_smote = smote.fit_resample(df2.iloc[:,0:-1], df2['TenYearCHD'])

print('Original dataset shape', len(df2))
print('Resampled dataset shape', len(y_smote))

# %%
#scatterplot to show that the datasets has been balanced after resampling through smote
plt.figure(figsize=(10,8))
sns.scatterplot(x=x_smote['totChol'],y=x_smote['glucose'],hue=y_smote,palette='husl')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# SMOTE works by utilizing a k-nearest neighbour algorithm to create synthetic data. SMOTE first starts by choosing random data from the minority class, then k-nearest neighbors from the data are set. Synthetic data would then be made between the random data and the randomly selected k-nearest neighbor.
#
# The procedure is repeated enough times until the minority class has the same proportion as the majority class.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# After resampling of data using smote it has created some synthetic data using KNN and from the plot it can be seen that the data has been balanced although the length has increased.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes its going to help in building model which will not be biased any more.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
#plotting heatmap to observe the correlation between independent variables and dependent variables
plt.figure(figsize=(15,10))
sns.set_palette('OrRd_r')
sns.heatmap(df2.corr(),annot=True)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A Heat map is a graphical representation of multivariate data that is structured as a matrix of columns and rows.
#
# Heat maps are very useful in describing correlation among several numerical variables, visualizing patterns and anomalies.
#
# Correlation is a dimensionless unit that determines the degree to which variables are related.
# It measures both strength and direction of the linear relationship between variables.
# Its value lies between 0 and 1, depicting strength.
# +ve and –ve signs depict direction.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Conclusion from Heatmap:-
#
# ●
# 1.sysBP and diaBP is positively correlated
#
#
# ●Systolic Blood Pressure. The normal range of systolic blood pressure should be 90 – 120 mm Hg.
#
# ●Diastolic Blood Pressure. The normal range of diastolic blood pressure should be 60 – 80 mm Hg.
#   IF The systolic pressure is high The diastolic pressure   should be low.
#
# 2.Glucose and diabetes are positively correlated.
#
# ●Diabetes is a disease that occurs when your blood glucose, also called blood sugar, is too high.
#
# 3.is_smoking and age is negatively correlated
#   indicating older age People have less habit of smoking.
#
# 4.prevalentHyp and sysBP is positively correlated.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
#creating columns of those features which have continuous datas along with sex column 
df2_cont_variables=df2[['sex','totChol','sysBP','diaBP','BMI','heartRate','glucose']]

# %%
df2_cont_variables

# %%
# Pair Plot visualization code
fig = plt.figure(figsize = (30,50))
my_palette = {0 : 'orange' , 1 : 'teal'}
sns.pairplot(df2_cont_variables,hue='sex',palette=my_palette)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pair plot is a data visualization that plots pair-wise relationships between all the variables of a dataset. This allows you to better understand the relationships visually, while even layering in additional details (such as by using color). Each variable is plotted both in the rows and columns, showing the relationships between the variables.The diagonal line shows the distribution of values in that variable using a histogram. Each other cell shows the relationship as a scatterplot between the two variables at their intersection.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Most of the variables are positively correlated and data in most of the features are rightly skewed.

# %% [markdown]
# ## ***5. Hypothesis Testing***

# %% [markdown]
# ### Based on your chart experiments, define three hypothetical statements from the dataset. In the next three questions, perform hypothesis testing to obtain final conclusion about the statements through your code and statistical testing.

# %% [markdown]
# Hypotheses are claims, and we can use statistics to prove or disprove them. At this point, hypothesis testing structures the problems so that we can use statistical evidence to test these claims. So we can check whether or not the claim is valid.
#
# **1. Defining Hypotheses**
#
#
# First of all, we should understand which scientific question we are looking for an answer to, and it should be formulated in the form of the Null Hypothesis (H₀) and the Alternative Hypothesis (H₁ or Hₐ). Please remember that H₀ and H₁ must be mutually exclusive, and H₁ shouldn’t contain equality:
#
# H₀: μ=x, H₁: μ≠x
#
# H₀: μ≤x, H₁: μ>x
#
# H₀: μ≥x, H₁: μ<x
#
#
# **2. Assumption Check**
#
#
# To decide whether to use the parametric or nonparametric version of the test, we should check the specific requirements listed below:
#
# Observations in each sample are independent and identically distributed (IID).
# Observations in each sample are normally distributed.
# Observations in each sample have the same variance.
#
#
# **Normality Tests**
#
# Shapiro-Wilk Test
#
# D’Agostino’s K^2 Test
#
# Anderson-Darling Test
#
# **Correlation Tests**
#
# Pearson’s Correlation Coefficient
#
# Spearman’s Rank Correlation
#
# Kendall’s Rank Correlation
#
# Chi-Squared Test
#
# **Stationary Tests**
#
# Augmented Dickey-Fuller
#
# Kwiatkowski-Phillips-Schmidt-Shin
#
# **Parametric Statistical Hypothesis Tests**
#
# Student’s t-test
#
# Paired Student’s t-test
#
# Analysis of Variance Test (ANOVA)
#
# Repeated Measures ANOVA Test
#
# **Nonparametric Statistical Hypothesis Tests**
#
# Mann-Whitney U Test
#
# Wilcoxon Signed-Rank Test
#
# Kruskal-Wallis H Test
#
# Friedman Test

# %% [markdown]
# ### Hypothetical Statement - 1

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# **1. Normality Tests**
#
# This section lists statistical tests that you can use to check if your data has a Gaussian distribution.
#
#
# Tests whether a data sample has a Gaussian distribution.
#
# Assumptions
#
# Observations in each sample are independent and identically distributed (iid).
#
# Interpretation
#
# H0: the sample has a Gaussian distribution.
#
# H1: the sample does not have a Gaussian distribution.

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Perform Statistical Test to obtain P-Value
# Example of the Shapiro-Wilk Normality Test
from scipy.stats import shapiro
for i in df2.columns:
  print('checking for column',i)
  stat, p = shapiro(df2[i])
  print('stat=%.3f, p=%.3f' % (stat, p))
  if p > 0.05:
   print('Probably Gaussian')
   print(' ')
  else:
   print('Probably not Gaussian')
   print(' ')

# %%
#Example of the D'Agostino's K^2 Normality Test
from scipy.stats import normaltest
for i in df2.columns:
  print('checking for column',i)
  stat, p = shapiro(df2[i])
  print('stat=%.3f, p=%.3f' % (stat, p))
  if p > 0.05:
   print('Probably Gaussian')
   print(' ')
  else:
   print('Probably not Gaussian')
   print(' ')

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### Hypothetical Statement - 2

# %% [markdown]
# **2. Correlation Tests**

# %% [markdown]
# Tests whether two samples have a linear relationship.
#
# **Assumptions**
#
# Observations in each sample are independent and identically distributed (iid).
#
# Observations in each sample are normally distributed.
#
# Observations in each sample have the same variance.

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# **Interpretation**
#
# H0: the two samples are independent.
#
# H1: there is a dependency between the samples.

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %% [markdown]
# #Pearson’s Correlation Coefficient

# %%
# Perform Statistical Test to obtain P-Value
# Example of the Pearson's Correlation test
from scipy.stats import pearsonr
for i in df2.columns:
  for j in df2.columns:
   print('corrrelation for',{i}, 'and',{j})
   stat, p = pearsonr(df2[i], df2[j])
   print('stat=%.3f, p=%.3f' % (stat, p))
   if p > 0.05:
    print('Probably independent')
    print(' ')
   else:
    print('Probably dependent')
    print(' ')

# %% [markdown]
# #Spearman’s Rank Correlation

# %%
# Example of the Spearman's Rank Correlation Test
from scipy.stats import spearmanr
for i in df2.columns:
  for j in df2.columns:
   print('corrrelation for',{i}, 'and',{j})
   stat, p = spearmanr(df2[i], df2[j])
   print('stat=%.3f, p=%.3f' % (stat, p))
   if p > 0.05:
    print('Probably independent')
    print(' ')
   else:
    print('Probably dependent')
    print(' ')

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### Hypothetical Statement - 3

# %% [markdown]
# # Parametric Statistical Hypothesis Tests

# %% [markdown]
# **Student’s t-test**
#
# Tests whether the means of two independent samples are significantly different.
#
# **Assumptions**
#
# Observations in each sample are independent and identically distributed (iid).
#
# Observations in each sample are normally distributed.
#
# Observations in each sample have the same variance

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# **Interpretation**
#
# H0: the means of the samples are equal.
#
# H1: the means of the samples are unequal.

# %%
# Example of the Student's t-test
from scipy.stats import ttest_ind
for i in df2.columns:
  for j in df2.columns:
   print('value for',{i}, 'and',{j})
   stat, p = ttest_ind(df2[i], df2[j])
   print('stat=%.3f, p=%.3f' % (stat, p))
   if p > 0.05:
    print('Probably the same distribution')
    print(' ')
   else:
    print('Probably different distributions')
    print(' ')

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Perform Statistical Test to obtain P-Value

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ## ***6. Feature Engineering & Data Pre-processing***

# %% [markdown]
# ### 1. Handling Missing Values

# %% [markdown]
# ## Missing data is defined as the values or data that is not stored (or not present) for some variable/s in the given dataset.In Pandas, usually, missing values are represented by NaN.

# %% [markdown]
# **Why Is Data Missing From The Dataset**
#
# There can be multiple reasons why certain values are missing from the data.
#
# Some of the reasons are listed below:
#
# Past data might get corrupted due to improper maintenance.
#
# Observations are not recorded for certain fields due to some reasons.
#
# There might be a failure in recording the values due to human error.
#
# The user has not provided the values intentionally.

# %% [markdown]
# **Why Do We Need To Care About Handling Missing Value?**
#
# Many machine learning algorithms fail if the dataset contains missing values. However, algorithms like K-nearest and Naive Bayes support data with missing values.
#
#
# We may end up building a biased machine learning model which will lead to incorrect results if the missing values are not handled properly.
#
#
# Missing data can lead to a lack of precision in the statistical analysis.

# %%
df2.head(50)

# %%
# Handling Missing Values & Missing Value Imputation
df.isnull().sum()

# %%
#checking the skewness in the datasets
for i in columns_null_values:
  print(df[i].skew())

# %% [markdown]
# **Most of the columns are rightly skewed**

# %%
#creating a copy of the original dataframe
data=df.copy()

# %%
#the first column which are having null values is education but it is not a good predictor parameter anad has no relation with CHD hence we will drop this column
data.drop(columns=['education'],inplace=True)

# %%
#next column which has null values is cigsPerDay

# %%
#checking the value counts of the column
data['cigsPerDay'].value_counts()

# %%
#looking at the cigsPerDay column most of the values int is 0 and also the median is 0 so we can fill the missing values with median or mode.
data['cigsPerDay'].median()

# %%
#filling the null value of cigsPerDay with median
data['cigsPerDay'].fillna(data['cigsPerDay'].median(),inplace=True)

# %%
data['cigsPerDay'].isnull().sum()

# %%
#next column which has null values are BPMeds,checking the value counts
data['BPMeds'].value_counts()

# %%
#checking the median of the datasets
data['BPMeds'].median()

# %%
#As in BPMeds column most frequent data is 0 also the median is 0 and it is rightly skewed so we will fill the null values with median

# %%
#filling the null values of BPMeds with median
data['BPMeds'].fillna(data['BPMeds'].median(),inplace=True)

# %%
data['BPMeds'].isnull().sum()

# %%
#filling the null values of BMI with median
data['BMI'].fillna(data['BMI'].median(),inplace=True)

# %%
#creating the list of remaining columns with null values
columns_null_values=['totChol','glucose']

# %%
#filling the null values with median as they are rightly skewed
for i in columns_null_values:
  data[i].fillna(data[i].median(),inplace=True)

# %%
data.isnull().sum()

# %% [markdown]
# #### What all missing value imputation techniques have you used and why did you use those techniques?

# %% [markdown]
# **How To Handle The Missing Data**
#
# Deleting the Missing values
#
#       Deleting the entire row
#       data = data.dropna(axis=0)
#
#       Deleting the entire column
#       data.drop(columns=['education'],inplace=True)
#
# Imputing the Missing Values
#
#       Replacing With Mean
#       data['columnname'] = data['columnname'].fillna(data['LoanAmount'].mean())
#
#       Replacing With Mode
#       data['columnname1'] = data['columnname1'].fillna(data['columnname1'].mode()[0])
#
#       Replacing With Median
#       data['BMI'].fillna(data['BMI'].median(),inplace=True)
#
#       Replacing with previous value – Forward fill
#       data['column'].fillna(method=‘ffill')
#
#       Replacing with next value – Backward fill
#       data['column'].fillna(method=‘bfill')
#
#       Impute the Most Frequent Value
#       from sklearn.impute import SimpleImputer
#       imputer = SimpleImputer(strategy='most_frequent')
#       imputer.fit_transform(data['column'])
#
#       from sklearn.impute import SimpleImputer
#       imp = SimpleImputer(missing_values=np.nan, strategy='mean')
#       imp.fit(data['column'])

# %% [markdown]
# ### 2. Handling Outliers

# %% [markdown]
# ***What are Outliers? ***
#
# An Outlier is an observation in a given dataset that lies far from the rest of the observations. That means an outlier is vastly larger or smaller than the remaining values in the set.An outlier may occur due to the variability in the data, or due to experimental error/human error.
#
# They may indicate an experimental error or heavy skewness in the data(heavy-tailed distribution).

# %% [markdown]
# **Detecting Outliers**
#
# Below are some of the techniques of detecting outliers
#
# Boxplots
#
#
#
#
# Z-score
#
# Inter Quantile Range(IQR)

# %% [markdown]
# **Detecting outliers using Boxplot:**

# %%
# Handling Outliers & Outlier treatments
cont_columns=['totChol','sysBP','diaBP','BMI','heartRate','glucose']
plt.figure(figsize=(8,15))
for i,j in enumerate(cont_columns):
  sns.set_palette('PuBuGn_r')
  plt.subplot(4,2,i+1)
  sns.boxplot(x=df2[j])

# %% [markdown]
# **Detecting outliers using the Z-scores**
#
# any data point whose Z-score falls out of 3rd standard deviation is an outlier.
#
# ![39536outlierdetection.png](data:image/png;base64,...)

# %%
#creating a function which will calculate the mean and median of the column and then calculate z-score to find outliers.
outliers = []
def detect_outliers_zscore(data):
    thres = 3
    mean = np.mean(data)
    std = np.std(data)
    # print(mean, std)
    for i in data:
        z_score = (i-mean)/std
        if (np.abs(z_score) > thres):
            outliers.append(i)
    return outliers

# %%
detect_outliers_zscore(df2['totChol'].values)

# %% [markdown]
# **Detecting outliers using the Inter Quantile Range(IQR)**
#
# data points that lie 1.5 times of IQR above Q3 and below Q1 are outliers. This shows in detail about outlier treatment in Python.
#
# steps:
# Sort the dataset in ascending order
#
# calculate the 1st and 3rd quartiles(Q1, Q3)
#
#
# compute IQR=Q3-Q1
#
#
# compute lower bound = (Q1–1.5*IQR), upper bound = (Q3+1.5*IQR)
#
#
# loop through the values of the dataset and check for those who fall below the lower bound and above the upper bound and mark them as outliers
# ![12311IQR.png](data:image/png;base64,...)

# %%
outliers1=[]
def outliers_detect_iqr(data):
  q1=np.percentile(data,25)
  q3=np.percentile(data,75)
  iqr=q3-q1
  lwr_bound=q1-(1.5*iqr)
  upr_bound=q3+(1.5*iqr)
  for i in data:
    if(i<lwr_bound or i>upr_bound):
      outliers1.append(i)
  return outliers1

# %%
outliers_detect_iqr(df2['totChol'])

# %% [markdown]
# **Handling Outliers**

# %%
#checking the distplot before outliers treatment
cont_columns=['totChol','sysBP','diaBP','BMI','heartRate','glucose']
plt.figure(figsize=(12,20))
for i,j in enumerate(cont_columns):
 sns.set_palette('flag_r')
 plt.subplot(4,2,i+1)
 sns.distplot(x=df2[j])
plt.show()

# %%
#checking the boxplot before removing outliers
cont_columns=['totChol','sysBP','diaBP','BMI','heartRate','glucose']
plt.figure(figsize=(8,15))
for i,j in enumerate(cont_columns):
  sns.set_palette('PuBuGn_r')
  plt.subplot(4,2,i+1)
  sns.boxplot(x=df2[j])

# %%
df3=df2.copy()

# %%
#log transformation
for i in cont_columns:
  df3[i]=np.log(df3[i])

# %%
#checking the distplot after outliers removal
cont_columns=['totChol','sysBP','diaBP','BMI','heartRate','glucose']
plt.figure(figsize=(12,20))
for i,j in enumerate(cont_columns):
 sns.set_palette('flag_r')
 plt.subplot(4,2,i+1)
 sns.distplot(x=df3[j])
plt.show()

# %%
#checking the boxplot after outliers treatment
cont_columns=['totChol','sysBP','diaBP','BMI','heartRate','glucose']
plt.figure(figsize=(8,15))
for i,j in enumerate(cont_columns):
  sns.set_palette('PuBuGn_r')
  plt.subplot(4,2,i+1)
  sns.boxplot(x=df3[j])

# %% [markdown]
# ##### What all outlier treatment techniques have you used and why did you use those techniques?

# %% [markdown]
# Below are some of the methods of treating the outliers
#
# Trimming/removing the outlier
#
# Quantile based flooring and capping
#
# Mean/Median imputation
#
# Log transformation.
#
#
# Removing outliers can result in some data loss so we will go with log transformation.
# Log transformation is commonly used for machine learning algorithms. It makes our model normal and the machine learning algorithm likes normal distribution data. There are some methods and features in machine learning algorithms such as scaling and normalization.

# %% [markdown]
# ### 3. Categorical Encoding

# %%
# Encode your categorical columns
#converting 'YES' to 1 and 'NO' to 0 in is_smoking column
df1['is_smoking']=np.where(df1['is_smoking']=='YES',1,0)

# %%
#converting 'F' to 0 and 'M' to 1
df1['sex']=np.where(df1['sex']=='F',0,1)

# %% [markdown]
# #### What all categorical encoding techniques have you used & why did you use those techniques?

# %% [markdown]
# **Different encoding techniques are:-**
#
#
#
# *
# Label Encoding or Ordinal Encoding
#
#
#
#
# We use this categorical data encoding technique when the categorical feature is ordinal. In this case, retaining the order is important. Hence encoding should reflect the sequence.
#
#           from sklearn import preprocessing
#           label_encoder = preprocessing.LabelEncoder()
#           df['column_name']= label_encoder.fit_transform(df['column_name'])
#
#
# *  One hot Encoding
#
#
#  We use this categorical data encoding technique when the features are nominal(do not have any order). In one hot encoding, for each level of a categorical feature, we create a new variable. Each category is mapped with a binary variable containing either 0 or 1. Here, 0 represents the absence, and 1 represents the presence of that category.
#
#           from sklearn.preprocessing import OneHotEncoder
#           enc=OneHotEncoder()
#           enc.fit_transform(df[column_name]).toarray()
#
#
#
#
#
#
#
# *   Dummy Encoding
#
#
# Dummy coding scheme is similar to one-hot encoding. This categorical data encoding method transforms the categorical variable into a set of binary variables (also known as dummy variables). In the case of one-hot encoding, for N categories in a variable, it uses N binary variables. The dummy encoding is a small improvement over one-hot-encoding. Dummy encoding uses N-1 features to represent N labels/categories.
#
#           data_encoded=pd.get_dummies(data)

# %% [markdown]
# ### 4. Textual Data Preprocessing
# (It's mandatory for textual dataset i.e., NLP, Sentiment Analysis, Text Clustering etc.)

# %% [markdown]
# #### 1. Expand Contraction

# %%
# Expand Contraction

# %% [markdown]
# #### 2. Lower Casing

# %%
# Lower Casing

# %% [markdown]
# #### 3. Removing Punctuations

# %%
# Remove Punctuations

# %% [markdown]
# #### 4. Removing URLs & Removing words and digits contain digits.

# %%
# Remove URLs & Remove words and digits contain digits

# %% [markdown]
# #### 5. Removing Stopwords & Removing White spaces

# %%
# Remove Stopwords

# %%
# Remove White spaces

# %% [markdown]
# #### 6. Rephrase Text

# %%
# Rephrase Text

# %% [markdown]
# #### 7. Tokenization

# %%
# Tokenization

# %% [markdown]
# #### 8. Text Normalization

# %%
# Normalizing Text (i.e., Stemming, Lemmatization etc.)

# %% [markdown]
# ##### Which text normalization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# #### 9. Part of speech tagging

# %%
# POS Taging

# %% [markdown]
# #### 10. Text Vectorization

# %%
# Vectorizing Text

# %% [markdown]
# ##### Which text vectorization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 4. Feature Manipulation & Selection

# %% [markdown]
# #### 1. Feature Manipulation

# %%
# Manipulate Features to minimize feature correlation and create new features

# %% [markdown]
# #### 2. Feature Selection

# %%
# Select your features wisely to avoid overfitting

# %% [markdown]
# ##### What all feature selection methods have you used  and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Which all features you found important and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 5. Data Transformation

# %% [markdown]
# #### Do you think that your data needs to be transformed? If yes, which transformation have you used. Explain Why?

# %% [markdown]
# Log Transform is the most used technique among data scientists. It’s mostly used to turn a skewed distribution into a normal or less-skewed distribution. We take the log of the values in a column and utilise those values as the column in this transform. It is used to handle confusing data, and the data becomes more approximative to normal applications.

# %%
# Transform Your data
#log transformation
for i in cont_columns:
  df3[i]=np.log(df3[i])

# %% [markdown]
# ### 6. Data Scaling

# %% [markdown]
# ##### Which method have you used to scale you data and why?

# %% [markdown]
# ### 7. Dimesionality Reduction

# %% [markdown]
# ##### Do you think that dimensionality reduction is needed? Explain Why?

# %% [markdown]
# Answer Here.

# %%
# DImensionality Reduction (If needed)

# %% [markdown]
# ##### Which dimensionality reduction technique have you used and why? (If dimensionality reduction done on dataset.)

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 8. Data Splitting

# %% [markdown]
# ##### What data splitting ratio have you used and why?

# %% [markdown]
# If the size of our dataset is between 100 to 10,00,000, then we split it in the ratio 60:20:20. That is 60% data will go to the Training Set, 20% to the Dev Set and remaining to the Test Set.I have choosen the test size 0.3 that is 30% for testing and 70% for training.

# %% [markdown]
# ### 9. Handling Imbalanced Dataset

# %% [markdown]
# Imbalanced data refers to those types of datasets where the target class has an uneven distribution of observations, i.e one class label has a very high number of observations and the other has a very low number of observations.
#
# ***Problems with imbalanced data classification ***
#
# If we explain it in a very simple manner, the main problem with imbalanced dataset prediction is how accurately are we actually predicting both majority and minority class.It means that the model fails to identify the minority class yet the accuracy score of the model will be high.

# %% [markdown]
# ##### Do you think the dataset is imbalanced? Explain Why.

# %%
#checking imbalance in the datasets
df3['TenYearCHD'].value_counts()

# %% [markdown]
# Yes our dataset is imbalanced as majority of the class belongs to 0 and very few belong to 1 so it may produce a bias model.

# %%
# Handling Imbalanced Dataset (If needed)
#scatterplot to show the imbalance in the target variable
plt.figure(figsize=(10,8))
sns.scatterplot(x=df3['totChol'],y=df3['glucose'],hue=df3['TenYearCHD'],palette='husl')

# %%
#using smote to resample the datasets so that it can be balanced
from imblearn.over_sampling import SMOTE

smote = SMOTE()

# fit predictor and target variable
x_smote1, y_smote1 = smote.fit_resample(df3.iloc[:,0:-1], df3['TenYearCHD'])

print('Original dataset shape', len(df3))
print('Resampled dataset shape', len(y_smote1))

# %%
#scatterplot to show that the datasets has been balanced after resampling through smote
plt.figure(figsize=(10,8))
sns.scatterplot(x=x_smote1['totChol'],y=x_smote1['glucose'],hue=y_smote1,palette='husl')

# %% [markdown]
# ##### What technique did you use to handle the imbalance dataset and why? (If needed to be balanced)

# %% [markdown]
# SMOTE works by utilizing a k-nearest neighbour algorithm to create synthetic data. SMOTE first starts by choosing random data from the minority class, then k-nearest neighbors from the data are set. Synthetic data would then be made between the random data and the randomly selected k-nearest neighbor.
#
# The procedure is repeated enough times until the minority class has the same proportion as the majority class.

# %% [markdown]
# ## #Data Scaling

# %% [markdown]
# **Normalization**
#
# All values are scaled in a specified range between 0 and 1 via normalisation (or min-max normalisation). This modification has no influence on the feature’s distribution, however it does exacerbate the effects of outliers due to lower standard deviations. As a result, it is advised that outliers be dealt with prior to normalisation.
#
# ![1_xIilonr1kVdoQRRvcpc1ng.png](data:image/png;base64,...)
#
#
# **Standardization:**
#
# Standardization (also known as z-score normalisation) is the process of scaling values while accounting for standard deviation. If the standard deviation of features differs, the range of those features will likewise differ. The effect of outliers in the characteristics is reduced as a result. To arrive at a distribution with a 0 mean and 1 variance, all the data points are subtracted by their mean and the result divided by the distribution’s variance.
#
# ![StandardizationFormula2-300x169.png](data:image/png;base64,...)
#
#
# ![1_HW7-kYjj6RKwrO-5WTLkDA.png](data:image/png;base64,...)

# %%
# Scaling your data
scaler=StandardScaler()
scaled_data_x=scaler.fit_transform(x_smote1)

# %% [markdown]
# # Data Splitting

# %% [markdown]
# In machine learning, data splitting is typically done to avoid overfitting. That is an instance where a machine learning model fits its training data too well and fails to reliably fit additional data.
#
# The original data in a machine learning model is typically taken and split into three or four sets. The three sets commonly used are the training set, the dev set and the testing set:

# %%
# Split your data to train and test. Choose Splitting ratio wisely.
X_train,X_test,y_train,y_test=train_test_split(scaled_data_x,y_smote1,test_size=0.3)

# %% [markdown]
# ## ***7. ML Model Implementation***

# %% [markdown]
# ### ML Model - 1

# %%
# ML Model - 1 Implementation

# Fit the Algorithm
clf1= LogisticRegression(fit_intercept=True, max_iter=10000)
clf1.fit(X_train, y_train)

# Predict on the model

# %%
#getting the coefficient of each feature
clf1.coef_

# %%
#getting the intercept
clf1.intercept_

# %%
#get the predicted probablities
train_pred=clf1.predict(X_train)
test_pred=clf1.predict(X_test)

# %%
# Get the accuracy scores
train_accuracy = accuracy_score(train_pred,y_train)
test_accuracy = accuracy_score(test_pred,y_test)

print("The accuracy on train data is ", train_accuracy)
print("The accuracy on test data is ", test_accuracy)

# %%
#getting to know the hyperparameters used in logistic regression algorithm
clf1.get_params()

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %% [markdown]
# Logistic regression (LR) is a statistical method similar to linear regression since LR finds an equation that predicts an outcome for a binary variable, Y, from one or more response variables, X. However, unlike linear regression the response variables can be categorical or continuous, as the model does not strictly require continuous data. To predict group membership, LR uses the log odds ratio rather than probabilities and an iterative maximum likelihood method rather than a least squares to fit the final model.
#
# Multiple Explanatory Variables
# An advantage of logistic regression is that it allows the evaluation of multiple explanatory variables by extension of the basic principles. The general equation is
#
# ![download.png](data:image/png;base64,...)

# %% [markdown]
# **EVALUATION METRICS:**
# 1. Confusion Matrix
#
# A confusion matrix is an N X N matrix, where N is the number of classes being predicted. For the problem in hand, we have N=2, and hence we get a 2 X 2 matrix. Here are a few definitions, you need to remember for a confusion matrix :
#
# **Accuracy** : the proportion of the total number of predictions that were correct.
#
#
# **Positive Predictive Value or Precision** : the proportion of positive cases that were correctly identified.
#
#
# **Negative Predictive Value** : the proportion of negative cases that were correctly identified.
#
#
# ***Sensitivity or Recall ***: the proportion of actual positive cases which are correctly identified.
#
#
# ***Specificity ***: the proportion of actual negative cases which are correctly identified.
#
#
#
# 2. F1 Score
#
#  F1-Score is the harmonic mean of precision and recall values for a classification problem. The formula for F1-Score is as follows:
#
# ![download (1).png](data:image/png;base64,...)

# %%
# Visualizing evaluation Metric Score chart
# Get the confusion matrix for train
labels = ['No Risk', 'At Risk']
cm = confusion_matrix(y_test, test_pred)
print(cm)
ax= plt.subplot()
sns.heatmap(cm, annot=True, ax = ax) #annot=True to annotate cells
# labels, title and ticks
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
#ax.set_title('Confusion Matrix for Logistic Regression Test predict')
ax.xaxis.set_ticklabels(labels)
ax.yaxis.set_ticklabels(labels)

# %%
# print acurracy and roc_auc score
print('ROCAUC score:', roc_auc_score(y_test, test_pred))
print("\n")
# Print the classification report for  test
print(classification_report(y_test, test_pred))

# %% [markdown]
# **Statsmodels** provides a Logit() function for performing logistic regression. The Logit() function accepts y and X as parameters and returns the Logit object. The model is then fitted to the data.

# %%
import statsmodels.api as sm
logit_model=sm.Logit(y_train,X_train)
result=logit_model.fit()
print(result.summary2())

# %% [markdown]
# From the above result it can be seen that there are some features whose p value is greater than 0.05 ,if we can apply the LogisticRegression model after dropping those columns then our model can be better.But before that lets do GridSearchCV.,i.e. hyperparameter tuning.

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning
#
# LogisticRegression with hyperparameter tuning.

# %%
# ML Model - 1 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)
#selecting the range for parameters
param_grid=[{'penalty' : ['l1', 'l2', 'elasticnet', 'none'],
    'C' : np.logspace(-4, 4, 20),
    'solver' : ['lbfgs','newton-cg','liblinear','sag','saga'],
    'max_iter' : [100, 1000,2500, 5000]
    
    }
]

# Fit the Algorithm
#creating GridSearchCV and fitting the data into it.
clf=GridSearchCV(clf1,param_grid=param_grid,cv=10)
#clf.fit(X_train,y_train)
# Predict on the model

# %%
#checking the best parameters after hyperparameter tuning
#clf.best_params_

# %%
#creating new logisticregression model with best hyperparameters and fitting the data into it
clf1=LogisticRegression(C=0.03359818286283781,max_iter=100,penalty= 'l1',solver='saga')
clf1.fit(X_train,y_train)

# %%
#predicting the value for test and train datasets
pred_test_cv=clf1.predict(X_test)
pred_train_cv=clf1.predict(X_train)

# %%
#checking accuracy score test datasets
accuracy_score(y_test,pred_test_cv)

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# ***Hyperparameter tuning using scikit-learn’s GridSearchCV ***is the greatest invention of all time. It runs through all the different parameters that is fed into the parameter grid and produces the best combination of parameters, based on a scoring metric of your choice (accuracy, f1, etc). Obviously, nothing is perfect and GridSearchCV is no exception:
#
# “best parameters” results are limited
# process is time-consuming
#
#
# The “best” parameters that GridSearchCV identifies are technically the best that could be produced, but only by the parameters that we included in our parameter grid.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# Yes we can se there is slight increament in the performance of the model after gridsearchCV.

# %% [markdown]
# **Another Logistin Regression Model after dropping some irrevelant columns**

# %%
df5=x_smote1.copy()

# %%
#dropping the columns which has greater p values
df5.drop(columns=['sex','is_smoking','BMI','heartRate'],axis=1,inplace=True)

# %%
#checking the first five rows
df5.head()

# %%
#creating independent variables
x=df5.iloc[:,0:10]

# %%
#creating dependent variable
y=y_smote1.copy()

# %%
#standardising the values of independent variables
X=scaler.fit_transform(x)

# %%
#splitting the datasets into train and test
X_train1,X_test1,y_train1,y_test1=train_test_split(X,y,test_size=0.3)

# %%
#creating object of LogisticRegression
reg=LogisticRegression()

# %%
#training the model
reg.fit(X_train1,y_train1)

# %%
#predicting the value of test datasets
pred1=reg.predict(X_test1)

# %%
#checking the accuracy by comparing actual value and predicted value
accuracy_score(y_test1,pred1)

# %%
#confusion matrix to check true positive or true negative
confusion_matrix(y_test1,pred1)

# %% [markdown]
# We can clearly observe the accuracy rate has not increased by a significant amount after dropping the columns.

# %% [markdown]
# ### ML Model - 2

# %% [markdown]
# #Decision Tree Classifiers

# %%
#standardised and balanced independent variable datasets
X_tree=scaler.fit_transform(x_smote1)
X_tree

# %%
#dependent variable
y_tree=y_smote1.values
y_tree

# %%
#splitting the data sets int train and test data sets
X_train2,X_test2,y_train2,y_test2=train_test_split(X_tree,y_tree,test_size=0.30)

# %%
#creating an object of DecisionTreeClassifier and fitting the data into it
dt_classifier=DecisionTreeClassifier(criterion='entropy', max_leaf_nodes=20, random_state=0)
dt_classifier.fit(X_train2,y_train2)

# %%
#predicting the values for x_test and x_train
pred_y_test=dt_classifier.predict(X_test2)
pred_y_train=dt_classifier.predict(X_train2)

# %%
#measuring accuracy score for test datasets
accuracy_score(y_test2,pred_y_test)

# %%
#measuring accuracy score for train datasets
accuracy_score(y_train2,pred_y_train)

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.
#
# **What is a Decision Tree?**
#
#
# It is a tool that has applications spanning several different areas. Decision trees can be used for classification as well as regression problems. The name itself suggests that it uses a flowchart like a tree structure to show the predictions that result from a series of feature-based splits. It starts with a root node and ends with a decision made by leaves.
#
# ![416511.png](data:image/png;base64,...)

# %% [markdown]
# Before learning more about decision trees let’s get familiar with some of the terminologies.
#
#
# Root Nodes – It is the node present at the beginning of a decision tree from this node the population starts dividing according to various features.
#
#
#
# Decision Nodes – the nodes we get after splitting the root nodes are called Decision Node
#
#
#
# Leaf Nodes – the nodes where further splitting is not possible are called leaf nodes or terminal nodes
#
#
#
# Sub-tree – just like a small portion of a graph is called sub-graph similarly a sub-section of this decision tree is called sub-tree.
#
#
#
# Pruning – is nothing but cutting down some nodes to stop overfitting.

# %% [markdown]
# Entropy
# Entropy is nothing but the uncertainty in our dataset or measure of disorder.
#
# The formula for Entropy is shown below:
#
# ![706025.png](data:image/png;base64,...)
#
# entropy Decision tree algorithm
# Here p+ is the probability of positive class
#
# p– is the probability of negative class
#
# S is the subset of the training example
#
# As mentioned earlier the goal of machine learning is to decrease the uncertainty or impurity in the dataset, here by using the entropy
#
# Information Gain
#
# Information gain measures the reduction of uncertainty given some feature and it is also a deciding factor for which attribute should be selected as a decision node or root node.
#
# ![410199.png](data:image/png;base64,...)

# %%
# Visualizing evaluation Metric Score chart
# Get the confusion matrix for train
labels = ['No Risk', 'At Risk']
cm = confusion_matrix(y_test2, pred_y_test)
print(cm)
ax= plt.subplot()
sns.heatmap(cm, annot=True, ax = ax) #annot=True to annotate cells
# labels, title and ticks
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
#ax.set_title('Confusion Matrix for Logistic Regression Test predict')
ax.xaxis.set_ticklabels(labels)
ax.yaxis.set_ticklabels(labels)

# %% [markdown]
# **Decision Tree with Hyperparameter Tuning**

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# ML Model - 1 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)

# Fit the Algorithm
#creating an object of decision tree,setting hyperparameters and doing gridsearchCV
dt_hp = DecisionTreeClassifier(random_state=43)

params = {'max_depth':[3,5,7,10,15],
          'min_samples_leaf':[3,5,10,15,20],
          'min_samples_split':[8,10,12,18,20,16],
          'criterion':['gini','entropy']}
GS = GridSearchCV(estimator=dt_hp,param_grid=params,cv=5,n_jobs=-1, verbose=True, scoring='accuracy')

#training the model with datasets
#GS.fit(X_train2,y_train2)

# Predict on the model

# %%
#getting best parameters
GS.best_params_

# %%
#getting best score
GS.best_score_

# %%
#creating object of decision tree with best hyperparameters which we obtained during gridsearchCV
dt_hp1 = DecisionTreeClassifier(criterion='gini',
 max_depth=15,
 min_samples_leaf=3,
 min_samples_split=8,random_state=43)

# %%
#training the model with datasets
dt_hp1.fit(X_train,y_train)

# %%
#predicting for train and test datasets
y_test_pred=dt_hp1.predict(X_test2)
y_train_pred=dt_hp1.predict(X_train2)

# %%
#calculating accuracy score for test datasets
accuracy_score(y_test_pred,y_test2)

# %%
#calculating accuracy score for train datasets
accuracy_score(y_train_pred,y_train2)

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# *Hyperparameter tuning using scikit-learn’s GridSearchCV *is the greatest invention of all time. It runs through all the different parameters that is fed into the parameter grid and produces the best combination of parameters, based on a scoring metric of your choice (accuracy, f1, etc). Obviously, nothing is perfect and GridSearchCV is no exception:
#
# “best parameters” results are limited process is time-consuming
#
# The “best” parameters that GridSearchCV identifies are technically the best that could be produced, but only by the parameters that we included in our parameter grid.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# It can be clearly seen the improvement in the prediction of the model.

# %% [markdown]
# #### 3. Explain each evaluation metric's indication towards business and the business impact pf the ML model used.

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### ML Model - 3

# %% [markdown]
# **Bagging:-**
#
# What Is Ensemble Learning?
#
#
# Ensemble learning is a widely used and preferred machine learning technique in which multiple individual models, often called base models, are combined to produce an effective optimal prediction model. The Random Forest algorithm is an example of ensemble learning.

# %%
# ML Model - 3 Implementation

# Fit the Algorithm
#creating an object of randon forest classifiers and training the model
rf=RandomForestClassifier()
rf.fit(X_train,y_train)

# Predict on the model

# %%
#predicting for train datasets
rf_predicted_y_train=rf.predict(X_train)

# %%
#predicting for test datasets
rf_predicted_y_test=rf.predict(X_test)

# %%
#accuracy score for test datasets
accuracy_score(y_test,rf_predicted_y_test)

# %%
#accuracy score for train datasets
accuracy_score(y_train,rf_predicted_y_train)

# %%
#printing classification report
print(classification_report(y_test,rf_predicted_y_test))

# %%
#knowing the best parameters used in algorithm
rf.get_params()

# %%
# Get the confusion matrix for train
labels = ['No Risk', 'At Risk']
cm = confusion_matrix(y_test, rf_predicted_y_test)
print(cm)
ax= plt.subplot()
sns.heatmap(cm, annot=True, ax = ax) #annot=True to annotate cells
# labels, title and ticks
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
#ax.set_title('Confusion Matrix for Random Forest Test predict')
ax.xaxis.set_ticklabels(labels)
ax.yaxis.set_ticklabels(labels)

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %% [markdown]
# **Random Forest Classifier**
#
#
# Random forest is a commonly- used machine learning algorithm, which combines the output of multiple decision trees to reach a single result. Its ease of use and flexibility have fueled its adoption, as it handles both classification and regression problems.
#
#
# Steps involved in random forest algorithm:
#
#
# Step 1: In Random forest n number of random records are taken from the data set having k number of records.
#
#
# Step 2: Individual decision trees are constructed for each sample.
#
#
# Step 3: Each decision tree will generate an output.
#
#
# Step 4: Final output is considered based on Majority Voting or Averaging for Classification and regression respectively.
#
# ![24015Random+Forest.jpg](data:image/jpeg;base64,...)

# %%
# Visualizing evaluation Metric Score chart

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %% [markdown]
# **Random Forest Classifier with hyperparameter tuning**

# %%
# ML Model - 3 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)
#random forest with hyperparameters setting
#rf1=RandomForestClassifier()
#grid_param={'n_estimators':[90,100,115,130],
 #           'criterion':['gini','entropy'],
  #          'max_depth':range(2,20,1),
 #           'min_samples_leaf':range(1,10,1),
   #         'min_samples_split':range(2,10,1),
    #        'max_features':['auto','log2']}
# Fit the Algorithm
#grid_search_rf=GridSearchCV(estimator=rf1,param_grid=grid_param,cv=5,n_jobs=-1,verbose=3)
#grid_search_rf.fit(X_train,y_train)
# Predict on the model
#y_grid_rf_test=grid_search_rf.predict(X_test)
#y_grid_rf_train=grid_search_rf.predict(X_train)

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# *Hyperparameter tuning using scikit-learn’s GridSearchCV *is the greatest invention of all time. It runs through all the different parameters that is fed into the parameter grid and produces the best combination of parameters, based on a scoring metric of your choice (accuracy, f1, etc). Obviously, nothing is perfect and GridSearchCV is no exception:
#
# “best parameters” results are limited process is time-consuming
#
# The “best” parameters that GridSearchCV identifies are technically the best that could be produced, but only by the parameters that we included in our parameter grid.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# Answer Here.

# %% [markdown]
# **Boosting Algorithm**
#
#
# Unlike many ML models which focus on high quality prediction done by a single model, boosting algorithms seek to improve the prediction power by training a sequence of weak models, each compensating the weaknesses of its predecessors.

# %% [markdown]
# #AdaBoost
#
# AdaBoost is a specific Boosting algorithm developed for classification problems (also called discrete AdaBoost). The weakness is identified by the weak estimator’s error rate:In each iteration, AdaBoost identifies miss-classified data points, increasing their weights (and decrease the weights of correct points, in a sense) so that the next classifier will pay extra attention to get them right.

# %%
#importing the algorithm and creating an object of it
from sklearn.ensemble import AdaBoostClassifier
ad_clf=AdaBoostClassifier()

# %%
#training the model with datasets
ad_clf.fit(X_train,y_train)

# %%
#predicting for train and test datasets
ad_test_pred=ad_clf.predict(X_test)
ad_train_pred=ad_clf.predict(X_train)

# %%
#calculating accuracy score for test datasets
accuracy_score(y_test,ad_test_pred)

# %%
#calculating accuracy score for train datasets
accuracy_score(y_train,ad_train_pred)

# %%
#printing classification report
print(classification_report(y_test,ad_test_pred))

# %%
#knowing the best parameters used in algorithm
ad_clf.get_params()

# %%
# Get the confusion matrix for train
labels = ['No Risk', 'At Risk']
cm = confusion_matrix(y_test, ad_test_pred)
print(cm)
ax= plt.subplot()
sns.heatmap(cm, annot=True, ax = ax) #annot=True to annotate cells
# labels, title and ticks
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
#ax.set_title('Confusion Matrix for AdaBoost Classifier Test predict')
ax.xaxis.set_ticklabels(labels)
ax.yaxis.set_ticklabels(labels)

# %% [markdown]
# #XGBoost
#
# XGBoost is an implementation of Gradient Boosted decision trees.
#
# In this algorithm, decision trees are created in sequential form. Weights play an important role in XGBoost. Weights are assigned to all the independent variables which are then fed into the decision tree which predicts results. The weight of variables predicted wrong by the tree is increased and these variables are then fed to the second decision tree. These individual classifiers/predictors then ensemble to give a strong and more precise model. It can work on regression, classification, ranking, and user-defined prediction problems.

# %%
#importing XGBoost and creating an object of it.
from xgboost import XGBClassifier
xgb_clf=XGBClassifier()

# %%
#training the datasets
xgb_clf.fit(X_train,y_train)

# %%
#predicting for train datasets and test datasets
xgb_train_pred=xgb_clf.predict(X_train)
xgb_test_pred=xgb_clf.predict(X_test)

# %%
#calculating accuracy score for test datasets
accuracy_score(y_test,xgb_test_pred)

# %%
#calculating accuracy score for train datasets
accuracy_score(y_train,xgb_train_pred)

# %%
#printing classificatio repport
print(classification_report(y_test,xgb_test_pred))

# %%
#knowing the best parameters used in model
xgb_clf.get_params()

# %%
# Get the confusion matrix for train
labels = ['No Risk', 'At Risk']
cm = confusion_matrix(y_test, xgb_test_pred)
print(cm)
ax= plt.subplot()
sns.heatmap(cm, annot=True, ax = ax) #annot=True to annotate cells
# labels, title and ticks
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
#ax.set_title('Confusion Matrix for XGBoost Classifier Test predict')
ax.xaxis.set_ticklabels(labels)
ax.yaxis.set_ticklabels(labels)

# %% [markdown]
# #K-Nearest Neighbors

# %% [markdown]
# K-Nearest Neighbours is one of the most basic yet essential classification algorithms in Machine Learning. It belongs to the supervised learning domain and finds intense application in pattern recognition, data mining and intrusion detection. It is widely disposable in real-life scenarios since it is non-parametric, meaning, it does not make any underlying assumptions about the distribution of data (as opposed to other algorithms such as GMM, which assume a Gaussian distribution of the given data).
#
# ![42452_2019_1329_Fig1_HTML.png](data:image/png;base64,...)

# %%
#creating the object of KNN
kn_clf=KNeighborsClassifier()
kn_clf.fit(X_train,y_train)

# %%
#Calculating accuracy score for test datasets
accuracy_score(y_test,kn_clf.predict(X_test))

# %%
accuracy_score(y_train,kn_clf.predict(X_train))

# %%
#printing classification report
print(classification_report(y_test,kn_clf.predict(X_test)))

# %%
#knowing the best parameters used in model
kn_clf.get_params()

# %%
#checking the accuracy score for test datasets for different values of k
for i in range(1,10):
  kn_clf1=KNeighborsClassifier(n_neighbors=i)
  kn_clf1.fit(X_train,y_train)
  kn_clf1.predict(X_test)
  print("the accuracy score for k =",accuracy_score(y_test,kn_clf1.predict(X_test)))

# %% [markdown]
# ### 1. Which Evaluation metrics did you consider for a positive business impact and why?

# %% [markdown]
# To evaluate the performance or quality of the model, different metrics are used, and these metrics are known as performance metrics or evaluation metrics. These performance metrics help us understand how well our model has performed for the given data. In this way, we can improve the model's performance by tuning the hyper-parameters.
#
# ![performance-metrics-in-machine-learning.png](data:image/png;base64,...)

# %% [markdown]
# To evaluate the performance of a classification model, different metrics are used, and some of them are as follows:
#
# Accuracy
#
# Confusion Matrix
#
# Precision
#
# Recall
#
# F-Score
#
# AUC(Area Under the Curve)-ROC

# %% [markdown]
# ## **I. Accuracy**
#
# The accuracy metric is one of the simplest Classification metrics to implement, and it can be determined as the number of correct predictions to the total number of predictions.
#
# ![performance-metrics-in-machine-learning2.png](data:image/png;base64,...)
#
#
# **When to Use Accuracy?**
#
# It is good to use the Accuracy metric when the target variable classes in data are approximately balanced.
#
# **When not to use Accuracy?**
#
# It is recommended not to use the Accuracy measure when the target variable majorly belongs to one class.

# %% [markdown]
# ## **II. Confusion Matrix**
#
# A confusion matrix is a tabular representation of prediction outcomes of any binary classifier, which is used to describe the performance of the classification model on a set of test data when true values are known.
#
#
# ![1_Z54JgbS4DUwWSknhDCvNTQ.png](data:image/png;base64,...)
#
#
# True Positive(TP): In this case, the prediction outcome is true, and it is true in reality, also.
#
# True Negative(TN): in this case, the prediction outcome is false, and it is false in reality, also.
#
# False Positive(FP): In this case, prediction outcomes are true, but they are false in actuality.
#
# False Negative(FN): In this case, predictions are false, and they are true in actuality.

# %% [markdown]
# # **III. Precision**
#
# The precision metric is used to overcome the limitation of Accuracy. The precision determines the proportion of positive prediction that was actually correct. It can be calculated as the True Positive or predictions that are actually true to the total positive predictions (True Positive and False Positive).
#
# ![performance-metrics-in-machine-learning4.png](data:image/png;base64,...)
#
# # **IV. Recall or Sensitivity**
# It is also similar to the Precision metric; however, it aims to calculate the proportion of actual positive that was identified incorrectly. It can be calculated as True Positive or predictions that are actually true to the total number of positives, either correctly predicted as positive or incorrectly predicted as negative (true Positive and false negative).
#
# ![performance-metrics-in-machine-learning5.png](data:image/png;base64,...)
#
#
# **When to use Precision and Recall?**
#
# From the above definitions of Precision and Recall, we can say that recall determines the performance of a classifier with respect to a false negative, whereas precision gives information about the performance of a classifier with respect to a false positive.
#
# So, if we want to minimize the false negative, then, Recall should be as near to 100%, and if we want to minimize the false positive, then precision should be close to 100% as possible.
#
# In simple words, if we maximize precision, it will minimize the FP errors, and if we maximize recall, it will minimize the FN error.

# %% [markdown]
# # **VI. AUC-ROC**
#
# Sometimes we need to visualize the performance of the classification model on charts; then, we can use the AUC-ROC curve. It is one of the popular and important metrics for evaluating the performance of the classification model.
#
#
# ROC represents a graph to show the performance of a classification model at different threshold levels. The curve is plotted between two parameters, which are:
#
# True Positive Rate
#
# False Positive Rate
#
# TPR or true Positive rate is a synonym for Recall, hence can be calculated as:
#
# ![performance-metrics-in-machine-learning7.png](data:image/png;base64,...)
#
# FPR or False Positive Rate can be calculated as:
#
# ![performance-metrics-in-machine-learning8.png](data:image/png;base64,...)
#
#
#
#
# ![performance-metrics-in-machine-learning9.png](data:image/png;base64,...)
#
#
# AUC calculates the performance across all the thresholds and provides an aggregate measure. The value of AUC ranges from 0 to 1. It means a model with 100% wrong prediction will have an AUC of 0.0, whereas models with 100% correct predictions will have an AUC of 1.0.
#
# **When to Use AUC**
#
# AUC should be used to measure how well the predictions are ranked rather than their absolute values. Moreover, it measures the quality of predictions of the model without considering the classification threshold.
#
# **When not to use AUC**
#
# As AUC is scale-invariant, which is not always desirable, and we need calibrating probability outputs, then AUC is not preferable.
#
# Further, AUC is not a useful metric when there are wide disparities in the cost of false negatives vs. false positives, and it is difficult to minimize one type of classification error.

# %% [markdown]
# ### 2. Which ML model did you choose from the above created models as your final prediction model and why?

# %% [markdown]
# RESULTS: Test Accuracies obtained on various ML algorithms:
#
# Logistic Regression= 0.6655092592592593,
#
# Logistic Regression(with hyperparameter tuning)= 0.6556712962962963
#
#  KNN= 0.7401620370370371
#
# Decision Tree Classifier()=0.6776620370370371,
#
# Random Forest Classifier(at no. of estimators:100)=0.8622685185185185,
#
# AdaBoost= 0.7100694444444444,
#
# XGBoost= 0.7702546296296297
#
# Among all RandomForest Classifier has best accuracy rate as it is a bagging algorithm.

# %% [markdown]
# ### 3. Explain the model which you have used and the feature importance using any model explainability tool?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ## ***8.*** ***Future Work (Optional)***

# %% [markdown]
# ### 1. Save the best performing ml model in a pickle file or joblib file format for deployment process.

# %%
# Save the File
import pickle as pkl
pickle_out1 = open("rf.pkl", "wb")  
pkl.dump(rf, pickle_out1)  
pickle_out1.close()

# %% [markdown]
# ### 2. Again Load the saved model file and try to predict unseen data for a sanity check.

# %%
# Load the File and predict unseen data.
 http://10.162.36.83:8503

# %% [markdown]
# ### ***Congrats! Your model is successfully created and ready for deployment on a live server for a real user interaction !!!***

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# #Findings and Applications
#
# 1.The elderly are more likely to suffer from various types of cardiovascular diseases.
#
# 2.Cholesterol level is a very important determinant in leading to cardiovascular diseases. The risks of getting cardiovascular diseases climb significantly when the cholesterol content in human body rises above the normal.
#
#
#
# 4.Physical activities help people become less susceptible to cardiovascular diseases.
#
# 5.A female non-smoker is less likely to have cardiovascular diseases, while a male smoker is less likely to get cardiovascular diseases.
#
# 6.As long as people have systolic blood pressure ≥ 126, they are classified as those susceptible to cardiovascular diseases. Therefore, high systolic blood pressure plays an important role in predicting that one experiences greater risks of suffering from cardiovascular diseases.
#
# 7.Among the three splitting factors, two of them are age. This suggests that apart from systolic blood pressure, age is the second most significant factor in deciding whether a person will have a chance of getting cardiovascular disease.

# %% [markdown]
# ##CONCLUSION

# %% [markdown]
# 1.As age increases the risk of getting diagnosed with heart disease also increases.
#
# 2.Cigarette consumption is also a major factor that causes CHDs.
#
# 3.Patients having Diabetes and cholesterol problems show a higher risk of CHDs.
#
# 4.Patients having high glucose levels are more prone to CHDs.
#
# 5.Patients with a history of “strokes” have a higher chance of developing CHDs.
#
# 6.Patients with high BMI(Body Mass Index) are at more risk of getting diagnosed with CHDs.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your Machine Learning Capstone Project !!!***
